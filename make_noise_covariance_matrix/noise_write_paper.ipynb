# %% [markdown]
# ## with smoothing and truncate |using 40GHzbeam w/o window function

# %%
include("function/calc_noise.jl")
freq_band = [40, 50, 60, 68, 78, 89, 100, 119, 140, 166, 195, 235, 280, 337, 402]
nside = 8
lmin = 2
#lmax = 8
lmax = 2nside
cl_th = truncate_noise_cov_mat_each_freq_calc_with_smoothing_40GHz_beam_wo_wl(freq_band, nside, lmin, lmax);

# %% [markdown]
# ## with smoothing and truncate using pixel size 2.5 beam w/o window

# %%
include("function/calc_noise.jl")
freq_band = [40, 50, 60, 68, 78, 89, 100, 119, 140, 166, 195, 235, 280, 337, 402]
nside = 8
lmin = 2
#lmax = 2nside
lmax = 8
cl_th = truncate_noise_cov_mat_each_freq_calc_with_smoothing_pixsize25_beam_wo_wl(freq_band, nside, lmin, lmax);

# %% [markdown]
# ## truncate w/o beam w/o window

# %%
include("function/calc_noise.jl")
#freq_band = [40, 50, 60, 68, 78, 89, 100, 119, 140, 166, 195, 235, 280, 337, 402]
freq_band = [60, 68, 78, 89, 100, 119, 140, 166, 195, 235, 280, 337, 402]
nside = 16
lmin = 2
#lmax = 8
lmax = 2nside
cl_th = truncate_noise_cov_mat_each_freq_calc_with_smoothing_wo_beam_wo_wl(freq_band, nside, lmin, lmax);

# %% [markdown]
# ## truncate w/o beam w/ window

# %%
include("function/calc_noise.jl")
#freq_band = [40, 50, 60, 68, 78, 89, 100, 119, 140, 166, 195, 235, 280, 337, 402]
freq_band = [60, 68, 78, 89, 100, 119, 140, 166, 195, 235, 280, 337, 402]
nside = 16
lmin = 2
#lmax = 8
lmax = 2nside
cl_th = truncate_noise_cov_mat_each_freq_calc_with_smoothing_wo_beam_w_wl(freq_band, nside, lmin, lmax);
